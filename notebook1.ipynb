# %%
import pandas as pd

# %%
#make data frame from csv 
df = pd.read_csv("./sheets/volcanoes.csv")
print(df.head())
# Out:
#    Unnamed: 0  id  year  month   day  tsunamiEventId  earthquakeEventId  \
# 0           0   1  1169    2.0   4.0          2852.0              421.0
# 1           1   2  1329    7.0   NaN             NaN                NaN
# 2           2   3  1883    3.0   NaN             NaN                NaN
# 3           3   4  1888    3.0  13.0          1175.0                NaN
# 4           4   5  1850    NaN   NaN             NaN                NaN
#
#    volcanoLocationId  volcanoLocationNewNum volcanoLocationNum  ...  \
# 0              10106                 211060           0101-06=  ...
# 1              10106                 211060           0101-06=  ...
# 2              30301                 233010           0303-01=  ...
# 3              50107                 251070           0501-07=  ...
# 4              50214                 252140           0502-14=  ...
#
#   injuriesAmountOrderTotal housesDestroyedAmountOrder housesDestroyed  \
# ...
